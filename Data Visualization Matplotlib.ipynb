# %% [markdown]
# <a href="https://colab.research.google.com/github/kofikyei/My_Datasets/blob/main/Data%20Visualization%20Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np# Numpy provides fast mathematical function processing
import pandas as pd # Pandas is used for easy indexing and data collection tools
import matplotlib as mpl # Machine learning libraries/ High Level Data Visualization library
import matplotlib.pyplot as plt #data visualization library
# %matplotlib inline

# %%
#My data is called Jobs so I named "Jobs" my dataframe(change the name of yours relative to data)
Jobs = pd.read_csv("https://raw.githubusercontent.com/kofikyei/My_Datasets/main/NYC_Jobs.csv", encoding ='latin1')

# %%
#This function provides your data
Jobs.head() # Without a value or integer it gives you the default head which is 5 rows
# Out:
#    Job ID                          Agency  ... Posting Updated  Process Date
# 0  438803           NYC HOUSING AUTHORITY  ...      03/31/2020    05/26/2020
# 1  431033         HUMAN RIGHTS COMMISSION  ...      01/29/2020    05/26/2020
# 2  271954  DEPT OF ENVIRONMENT PROTECTION  ...      11/16/2016    05/26/2020
# 3  391119  DEPT OF ENVIRONMENT PROTECTION  ...      04/22/2019    05/26/2020
# 4  414748           NYC HOUSING AUTHORITY  ...      11/21/2019    05/26/2020
#
# [5 rows x 30 columns]

# %%
#gives a list of column names
Jobs.columns.values
# Out:
# array(['Job ID', 'Agency', 'Posting Type', '# Of Positions',
#        'Business Title', 'Civil Service Title', 'Title Classification',
#        'Title Code No', 'Level', 'Job Category',
#        'Full-Time/Part-Time indicator', 'Career Level',
#        'Salary Range From', 'Salary Range To', 'Salary Frequency',
#        'Work Location', 'Division/Work Unit', 'Job Description',
#        'Minimum Qual Requirements', 'Preferred Skills',
#        'Additional Information', 'To Apply', 'Hours/Shift',
#        'Work Location 1', 'Recruitment Contact', 'Residency Requirement',
#        'Posting Date', 'Post Until', 'Posting Updated', 'Process Date'],
#       dtype=object)

# %%
#Give size of data you have upload
Jobs.shape
# Out:
# (1666, 30)

# %%
#Presents all of data
Jobs
# Out:
#       Job ID                          Agency  ... Posting Updated  Process Date
# 0     438803           NYC HOUSING AUTHORITY  ...      03/31/2020    05/26/2020
# 1     431033         HUMAN RIGHTS COMMISSION  ...      01/29/2020    05/26/2020
# 2     271954  DEPT OF ENVIRONMENT PROTECTION  ...      11/16/2016    05/26/2020
# 3     391119  DEPT OF ENVIRONMENT PROTECTION  ...      04/22/2019    05/26/2020
# 4     414748           NYC HOUSING AUTHORITY  ...      11/21/2019    05/26/2020
# ...      ...                             ...  ...             ...           ...
# 1661  364993     DEPARTMENT OF INVESTIGATION  ...      03/24/2020    05/26/2020
# 1662  400522       OFFICE OF THE COMPTROLLER  ...      02/04/2020    05/26/2020
# 1663  440446     HRA/DEPT OF SOCIAL SERVICES  ...      05/22/2020    05/26/2020
# 1664  426767     TAXI & LIMOUSINE COMMISSION  ...      01/28/2020    05/26/2020
# 1665  383739  DEPT OF ENVIRONMENT PROTECTION  ...      04/02/2019    05/26/2020
#
# ...

# %%
#
Jobs.plot

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.bar(x="Salary Range To", y="# Of Positions")
plt.title("Bar Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.line(x="Salary Range To", y="# Of Positions")
plt.title("Line Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.hist(x="Salary Range To", y="# Of Positions")
plt.title("Histogram Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.box(x="Salary Range To", y="# Of Positions")
plt.title("Boxplot Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.pie(x="Salary Range To", y="# Of Positions")
plt.title("Pie Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns ### How does Salary Range(X variable) affects number of available position)(Y variable))
# dependent variables
#independent variables
Jobs2 =Jobs.plot.scatter(x="Salary Range To", y="# Of Positions")
plt.title("Scatter Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.area(x="Salary Range To", y="# Of Positions")
plt.title("Area Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Rename Dataframe to not overwrite original
# Execute code
# Pick two columns
Jobs2 =Jobs.plot.scatter(x="Salary Range To", y="# Of Positions")
plt.title("Scatter Plot")
plt.xlabel("Salary Range To")
plt.ylabel("# of Positions")
plt.rcParams['figure.figsize']={10,4}
plt.show
# Out:
# <function matplotlib.pyplot.show>
